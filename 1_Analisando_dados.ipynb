# %% [markdown]
# <a href="https://colab.research.google.com/github/Fhupsel/Projetos_Dados/blob/main/1_Analisando_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Análise de dados de uma empresa fictícia usando a biblioteca Pandas
# [Planilha](https://onedrive.live.com/edit.aspx?action=edit&resid=E5C3E67C0A809DAF!106&ithint=file%2cxlsx&action=edit&wdNewAndOpenCt=1660828547546&wdPreviousSession=c1dd4535-82f0-4829-85b9-a313c13dc8aa&wdOrigin=OFFICECOM-WEB.START.UPLOAD)

# %%
import pandas as pd
p = pd.read_excel('/controle_da_empresa.xlsx', None)
est = p["Estoque"]
ven = p["Vendas"]
fun = p["Funcionários"]

# %%
est
# Out:
#    Código                 Item  Estoque Mínimo  Custo da Unidade  \
# 0  SIG001     Canon 6D Mark II               5              8500
# 1  SIG002    Canon 5D Mark III               2              9500
# 2  SIG003     Lente 85mm f/1.4               8              7000
# 3  SIG004     Lente 50mm f/1.4               8               900
# 4  SIG005  Lente 16-35mm f/2.8               8              6120
# 5  SIG006     Filtro ND 2 Stop               2               450
# 6  SIG007     Filtro ND 3 Stop               2               450
# 7  SIG008     Filtro ND 5 Stop               2               450
# 8  SIG009      DJI Mavic Air 2               1             10890
# 9  SIG010          DJI Ronin-S               1              3980
#
#    Preço da Unidade Unidade de Medida  Estoque Atual
# 0              8500           Unidade             13
# 1             13650           Unidade              1
# 2              9989           Unidade              6
# ...

# %%
ven
# Out:
#    Data da Venda                 Item  Quantidade  Vendedor  Preço Unitário  \
# 0     2020-01-02     Lente 50mm f/1.4           2    Carlos            1649
# 1     2020-01-02     Filtro ND 5 Stop           2    Raquel            1220
# 2     2020-01-03     Filtro ND 5 Stop           2    Raquel            1220
# 3     2020-01-03  Lente 16-35mm f/2.8           2    Carlos            8997
# 4     2020-01-04  Lente 16-35mm f/2.8           2  Fernanda            8997
# ..           ...                  ...         ...       ...             ...
# 85    2020-01-29     Filtro ND 5 Stop           2      Theo            1220
# 86    2020-01-29  Lente 16-35mm f/2.8           2      Theo            8997
# 87    2020-01-29     Filtro ND 2 Stop           1  Fernanda            1220
# 88    2020-01-30     Filtro ND 3 Stop           2  Fernanda            1220
# 89    2020-01-30     Filtro ND 5 Stop           2    Raquel            1220
#
#     Total de Vendas
# 0              3298
# ...

# %%
ven["Data da Venda"]
# Out:
# 0    2020-01-02
# 1    2020-01-02
# 2    2020-01-03
# 3    2020-01-03
# 4    2020-01-04
#         ...
# 85   2020-01-29
# 86   2020-01-29
# 87   2020-01-29
# 88   2020-01-30
# 89   2020-01-30
# Name: Data da Venda, Length: 90, dtype: datetime64[ns]

# %%
#Analisando melhor dia de venda
ven["Data da Venda"].apply(lambda x: x.weekday()).hist(bins=7)

# %% [markdown]
# Melhores dias de venda:
#
# Dia 1 - Terça
#
# Dia 3 - Quinta

# %%
fun
# Out:
#   Funcionário  Total de Vendas
# 0      Carlos           205301
# 1    Fernanda           204982
# 2        Theo           272816
# 3      Raquel           172700

# %%
#Vendedor com mais vendas
fun.max()
# Out:
# Funcionário          Theo
# Total de Vendas    272816
# dtype: object
